# %% [markdown]
# # 10-tip balanced coalescent tree analysis

# %% [markdown]
# The topology for this simcat analysis is a 10-tip, imbalanced, bifurcating tree. The database of simulations used here was simulated outside of this notebook. Each sample has 20,000 SNPs. Ech simulation allowed for each node to slide up and down 25% of its height, for each branch to take a different Ne value, and for the root position to shift between 0.5 and 1.5 times its original depth. The timing of the admixture edge varied from .3 to .7, and the magnitude varied from 0.05 to 0.5.

# %% [markdown]
# ## Imports:

# %%
import simcat
import toytree
import toyplot
import toyplot.svg
import numpy as np
import pandas as pd
import h5py
import csv
from keras.models import Sequential,load_model
from keras.layers import Dense
from sklearn.metrics import accuracy_score, confusion_matrix
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load up database:
# This is a huge database with over 60,000 ipcoal simulations.

# %%
mod = simcat.Analysis(
    name="cleaned",
    workdir="../merged/",
    mask_admixture_min=0.05,
    mask_sisters=True,
    scale=1,
)
# Out:
# [init] cleaned
# [load] (63740, 210, 16, 16)
# [filter] (63740, 210, 16, 16)
# [vectorize] (63740, 53760)
# [train/test] (42705, 53760)/(21035, 53760)

# %%
mod.train_test_split(prop=0.1)
# Out:
# [train/test] (57366, 53760)/(6374, 53760)

# %% [markdown]
# ## Look at the tree:

# %%
mod.tree.draw(ts='p');
# Out:
# <div class="toyplot" id="t36e6b7396b8d4d2d81f8be29212d2c0f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="ta2e864954bb342c2be5a69a8529504bd" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t49309645e2f6476e8f3dd24a780c26ac"><clipPath id="t8f70f855116941e5b7e9bef1d15b47df"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t8f70f855116941e5b7e9bef1d15b47df)"><g class="toyplot-mark-Graph" id="t77268e0a6c314743b23e8578cd35f1ed"><g class="toyplot-Edges"><path d="M 280.53866936845657 122.72727272727273 L 293.7310030395136 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 280.53866936845657 122.72727272727273 L 267.34633569739947 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 250.85591860857812 86.36363636363637 L 280.53866936845657 122.72727272727273" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 221.17316784869973 122.72727272727273 L 240.96166835528533 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 201.3846673421141 159.0909090909091 L 214.57700101317118 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 201.3846673421141 159.0909090909091 L 188.19233367105704 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 221.17316784869973 122.72727272727273 L 201.3846673421141 159.0909090909091" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 250.85591860857812 86.36363636363637 L 221.17316784869973 122.72727272727273" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 184.89425025329277 50.0 L 250.85591860857812 86.36363636363637" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 148.6153326578858 122.72727272727273 L 161.8076663289429 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 148.6153326578858 122.72727272727273 L 135.42299898682876 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 118.93258189800741 86.36363636363637 L 148.6153326578858 122.72727272727273" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 89.249831138129 122.72727272727273 L 109.03833164471462 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 69.46133063154339 159.0909090909091 L 82.65366430260046 195.45454545454544" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 69.46133063154339 159.0909090909091 L 56.26899696048632 195.45454545454544" ...

# %% [markdown]
# ## Fit a neural network:

# %% [markdown]
# #### Prepare the data:

# %%
# encode labels as ints:
unique_labs = np.unique(mod.y)
onehot_dict = dict(zip(range(len(unique_labs)),unique_labs))
inv_onehot_dict = dict(zip(unique_labs,range(len(unique_labs))))

# %% [markdown]
# #### Write out the dict so you can interpret your predictions later on...
# We'll use it when we load up the results to use on other data, later.

# %%
with open('onehot_dict.csv', 'w') as f:  # Just use 'w' mode in 3.x
    w = csv.DictWriter(f, onehot_dict.keys())
    w.writeheader()
    w.writerow(onehot_dict)

# %%
# number of non-sister admixture scenarios in our training data
len(onehot_dict)
# Out:
# 177

# %% [markdown]
# #### Now actually create one-hot-encoded labels for the training and testing

# %%
# one-hot encode training labels
y_idxs = [inv_onehot_dict[i] for i in np.array(mod.y_train)]
y = np.zeros((len(y_idxs),len(onehot_dict)))
for rowidx in range(y.shape[0]):
    y[rowidx,y_idxs[rowidx]] += 1

# %%
# one-hot encode test labels
y_test_idxs = [inv_onehot_dict[i] for i in np.array(mod.y_test)]
y_test = np.zeros((len(y_test_idxs),len(onehot_dict)))
for rowidx in range(y_test.shape[0]):
    y_test[rowidx,y_test_idxs[rowidx]] += 1

# %% [markdown]
# #### Record which of these onehot values maps to "NaN", indicating that there was introgression between sister edges. We don't want to include this in the training.

# %%
# for excluding NaN from the analysis -- which integer value is NaN?
nanval = {onehot_dict[i]:i for i in onehot_dict.keys()}["NaN"]

# %% [markdown]
# ## The data is prepared. Now train the model:
# For this analysis, at each stage, we're going to exclude the data that has the "NaN" label.

# %% [markdown]
# ### Define the network:
# We'll have one hidden layer with 1000 nodes.

# %%
# Neural network architecture
model = Sequential()
model.add(Dense(1000, input_dim=mod.X_train.shape[1], activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Do the training:
# At each epoch, let's evaluate the model's accuracy on a separate test dataset that doesn't impact the model training.

# %%
num_epochs = 75
epoch_accuracies = []
test_accuracies = []
for i in range(num_epochs):
    print("~~~~~~~~~~~~~~ Training epoch "+ str(i) + ": ~~~~~~~~~~~~~~")
    history = model.fit(mod.X_train[~(np.argmax(y,1)==nanval)], 
                        y[~(np.argmax(y,1)==nanval)], 
                        epochs=1, 
                        batch_size=512,
                        verbose=False)
    acc = history.history['accuracy']
    print("training accuracy: " + str(round(acc[0],2)))
    epoch_accuracies.append(acc[0])
    
    # now make predictions on the test data
    y_pred = model.predict(mod.X_test[~(np.argmax(y_test,1)==nanval)])
    #Convert predictions to label
    pred = list()
    for i in range(len(y_pred)):
        pred.append(np.argmax(y_pred[i]))
        
    #Converting one hot encoded test label to label
    test = list()
    for i in range(len(y_test[~(np.argmax(y_test,1)==nanval)])):
        test.append(np.argmax(y_test[~(np.argmax(y_test,1)==nanval)][i]))
        
    a = accuracy_score(pred,test)
    print("test accuracy: "+str(round(a,2)))
    test_accuracies.append(a)
# Out:
# ~~~~~~~~~~~~~~ Training epoch 0: ~~~~~~~~~~~~~~
# training accuracy: 0.02
# test accuracy: 0.06
# ~~~~~~~~~~~~~~ Training epoch 1: ~~~~~~~~~~~~~~
# training accuracy: 0.09
# test accuracy: 0.13
# ~~~~~~~~~~~~~~ Training epoch 2: ~~~~~~~~~~~~~~
# training accuracy: 0.17
# test accuracy: 0.22
# ~~~~~~~~~~~~~~ Training epoch 3: ~~~~~~~~~~~~~~
# training accuracy: 0.25
# test accuracy: 0.28
# ~~~~~~~~~~~~~~ Training epoch 4: ~~~~~~~~~~~~~~
# training accuracy: 0.31
# test accuracy: 0.32
# ~~~~~~~~~~~~~~ Training epoch 5: ~~~~~~~~~~~~~~
# training accuracy: 0.36
# test accuracy: 0.37
# ~~~~~~~~~~~~~~ Training epoch 6: ~~~~~~~~~~~~~~
# training accuracy: 0.41
# test accuracy: 0.41
# ~~~~~~~~~~~~~~ Training epoch 7: ~~~~~~~~~~~~~~
# training accuracy: 0.44
# test accuracy: 0.44
# ~~~~~~~~~~~~~~ Training epoch 8: ~~~~~~~~~~~~~~
# training accuracy: 0.47
# test accuracy: 0.48
# ~~~~~~~~~~~~~~ Training epoch 9: ~~~~~~~~~~~~~~
# training accuracy: 0.5
# test accuracy: 0.5
# ~~~~~~~~~~~~~~ Training epoch 10: ~~~~~~~~~~~~~~
# training accuracy: 0.52
# test accuracy: 0.52
# ~~~~~~~~~~~~~~ Training epoch 11: ~~~~~~~~~~~~~~
# training accuracy: 0.54
# test accuracy: 0.53
# ~~~~~~~~~~~~~~ Training epoch 12: ~~~~~~~~~~~~~~
# training accuracy: 0.55
# test accuracy: 0.54
# ~~~~~~~~~~~~~~ Training epoch 13: ~~~~~~~~~~~~~~
# training accuracy: 0.56
# test accuracy: 0.56
# ~~~~~~~~~~~~~~ Training epoch 14: ~~~~~~~~~~~~~~
# training accuracy: 0.57
# test accuracy: 0.58
# ~~~~~~~~~~~~~~ Training epoch 15: ~~~~~~~~~~~~~~
# training accuracy: 0.59
# test accuracy: 0.58
# ~~~~~~~~~~~~~~ Training epoch 16: ~~~~~~~~~~~~~~
# training accuracy: 0.59
# test accuracy: 0.58
# ~~~~~~~~~~~~~~ Training epoch 17: ~~~~~~~~~~~~~~
# training accuracy: 0.6
# test accuracy: 0.6
# ~~~~~~~~~~~~~~ Training epoch 18: ~~~~~~~~~~~~~~
# training accuracy: 0.61
# test accuracy: 0.61
# ~~~~~~~~~~~~~~ Training epoch 19: ~~~~~~~~~~~~~~
# training accuracy: 0.62
# test accuracy: 0.6
# ~~~~~~~~~~~~~~ Training epoch 20: ~~~~~~~~~~~~~~
# training accuracy: 0.63
# test accuracy: 0.62
# ~~~~~~~~~~~~~~ Training epoch 21: ~~~~~~~~~~~~~~
# training accuracy: 0.63
# test accuracy: 0.63
# ~~~~~~~~~~~~~~ Training epoch 22: ~~~~~~~~~~~~~~
# training accuracy: 0.64
# test accuracy: 0.61
# ~~~~~~~~~~~~~~ Training epoch 23: ~~~~~~~~~~~~~~
# training accuracy: 0.64
# test accuracy: 0.63
# ~~~~~~~~~~~~~~ Training epoch 24: ~~~~~~~~~~~~~~
# training accuracy: 0.65
# test accuracy: 0.64
# ~~~~~~~~~~~~~~ Training epoch 25: ~~~~~~~~~~~~~~
# training accuracy: 0.65
# test accuracy: 0.64
# ~~~~~~~~~~~~~~ Training epoch 26: ~~~~~~~~~~~~~~
# training accuracy: 0.66
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 27: ~~~~~~~~~~~~~~
# training accuracy: 0.67
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 28: ~~~~~~~~~~~~~~
# training accuracy: 0.67
# test accuracy: 0.64
# ~~~~~~~~~~~~~~ Training epoch 29: ~~~~~~~~~~~~~~
# training accuracy: 0.67
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 30: ~~~~~~~~~~~~~~
# training accuracy: 0.68
# test accuracy: 0.65
# ~~~~~~~~~~~~~~ Training epoch 31: ~~~~~~~~~~~~~~
# training accuracy: 0.68
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 32: ~~~~~~~~~~~~~~
# training accuracy: 0.68
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 33: ~~~~~~~~~~~~~~
# training accuracy: 0.69
# test accuracy: 0.68
# ~~~~~~~~~~~~~~ Training epoch 34: ~~~~~~~~~~~~~~
# training accuracy: 0.69
# test accuracy: 0.66
# ~~~~~~~~~~~~~~ Training epoch 35: ~~~~~~~~~~~~~~
# training accuracy: 0.7
# test accuracy: 0.68
# ~~~~~~~~~~~~~~ Training epoch 36: ~~~~~~~~~~~~~~
# training accuracy: 0.7
# test accuracy: 0.68
# ~~~~~~~~~~~~~~ Training epoch 37: ~~~~~~~~~~~~~~
# training accuracy: 0.7
# test accuracy: 0.7
# ~~~~~~~~~~~~~~ Training epoch 38: ~~~~~~~~~~~~~~
# training accuracy: 0.71
# test accuracy: 0.68
# ~~~~~~~~~~~~~~ Training epoch 39: ~~~~~~~~~~~~~~
# training accuracy: 0.71
# test accuracy: 0.69
# ~~~~~~~~~~~~~~ Training epoch 40: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.69
# ~~~~~~~~~~~~~~ Training epoch 41: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.69
# ~~~~~~~~~~~~~~ Training epoch 42: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.68
# ~~~~~~~~~~~~~~ Training epoch 43: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.7
# ~~~~~~~~~~~~~~ Training epoch 44: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.7
# ~~~~~~~~~~~~~~ Training epoch 45: ~~~~~~~~~~~~~~
# training accuracy: 0.72
# test accuracy: 0.7
# ~~~~~~~~~~~~~~ Training epoch 46: ~~~~~~~~~~~~~~
# training accuracy: 0.73
# test accuracy: 0.69
# ~~~~~~~~~~~~~~ Training epoch 47: ~~~~~~~~~~~~~~
# training accuracy: 0.73
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 48: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 49: ~~~~~~~~~~~~~~
# training accuracy: 0.73
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 50: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 51: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.69
# ~~~~~~~~~~~~~~ Training epoch 52: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 53: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 54: ~~~~~~~~~~~~~~
# training accuracy: 0.74
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 55: ~~~~~~~~~~~~~~
# training accuracy: 0.75
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 56: ~~~~~~~~~~~~~~
# training accuracy: 0.75
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 57: ~~~~~~~~~~~~~~
# training accuracy: 0.75
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 58: ~~~~~~~~~~~~~~
# training accuracy: 0.76
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 59: ~~~~~~~~~~~~~~
# training accuracy: 0.75
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 60: ~~~~~~~~~~~~~~
# training accuracy: 0.75
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 61: ~~~~~~~~~~~~~~
# training accuracy: 0.76
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 62: ~~~~~~~~~~~~~~
# training accuracy: 0.76
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 63: ~~~~~~~~~~~~~~
# training accuracy: 0.76
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 64: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.74
# ~~~~~~~~~~~~~~ Training epoch 65: ~~~~~~~~~~~~~~
# training accuracy: 0.76
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 66: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.72
# ~~~~~~~~~~~~~~ Training epoch 67: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.74
# ~~~~~~~~~~~~~~ Training epoch 68: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.71
# ~~~~~~~~~~~~~~ Training epoch 69: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.74
# ~~~~~~~~~~~~~~ Training epoch 70: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 71: ~~~~~~~~~~~~~~
# training accuracy: 0.77
# test accuracy: 0.73
# ~~~~~~~~~~~~~~ Training epoch 72: ~~~~~~~~~~~~~~
# training accuracy: 0.78
# test accuracy: 0.74
# ~~~~~~~~~~~~~~ Training epoch 73: ~~~~~~~~~~~~~~
# training accuracy: 0.78
# test accuracy: 0.74
# ~~~~~~~~~~~~~~ Training epoch 74: ~~~~~~~~~~~~~~
# training accuracy: 0.78
# test accuracy: 0.73

# %% [markdown]
# #### You can see that the model is scoring around 74% on the test dataset.

# %% [markdown]
# ### Save the trained model to load up later.

# %%
model.save("bal_10tip_2mil_mod_20ksnps_1000node.h5")
